# %%
import polars as pl
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
df = pl.read_csv("../hospital_readmission_dataset.csv")
df.head()
# Out:
# shape: (5, 17)
# ┌────────────┬──────────────┬────────┬─────┬───┬──────────────┬──────────────┬─────────────┬───────┐
# │ patient_id ┆ admission_da ┆ season ┆ age ┆ … ┆ insurance_ty ┆ discharge_di ┆ readmission ┆ label │
# │ ---        ┆ te           ┆ ---    ┆ --- ┆   ┆ pe           ┆ sposition    ┆ _risk_score ┆ ---   │
# │ str        ┆ ---          ┆ str    ┆ i64 ┆   ┆ ---          ┆ ---          ┆ ---         ┆ i64   │
# │            ┆ str          ┆        ┆     ┆   ┆ str          ┆ str          ┆ f64         ┆       │
# ╞════════════╪══════════════╪════════╪═════╪═══╪══════════════╪══════════════╪═════════════╪═══════╡
# │ P00001     ┆ 2022-04-14   ┆ Spring ┆ 66  ┆ … ┆ Medicare     ┆ Home Health  ┆ 0.92        ┆ 1     │
# │ P00002     ┆ 2021-09-19   ┆ Fall   ┆ 55  ┆ … ┆ Private      ┆ Home Health  ┆ 0.88        ┆ 1     │
# │ P00003     ┆ 2023-04-12   ┆ Spring ┆ 69  ┆ … ┆ Medicare     ┆ Skilled      ┆ 0.97        ┆ 1     │
# │            ┆              ┆        ┆     ┆   ┆              ┆ Nursing      ┆             ┆       │
# │ P00004     ┆ 2023-08-14   ┆ Summer ┆ 83  ┆ … ┆ Medicare     ┆ Skilled      ┆ 0.97        ┆ 1     │
# │            ┆              ┆        ┆     ┆   ┆              ┆ Nursing      ┆             ┆       │
# │ P00005     ┆ 2021-11-05   ┆ Fall   ┆ 54  ┆ … ┆ Uninsured    ┆ Home Health  ┆ 0.83        ┆ 1     │
# └────────────┴──────────────┴────────┴─────┴───┴──────────────┴──────────────┴─────────────┴───────┘

# %%
df.describe()
# Out:
# shape: (9, 18)
# ┌────────────┬────────────┬────────────┬────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic  ┆ patient_id ┆ admission_ ┆ season ┆ … ┆ insurance ┆ discharge ┆ readmissi ┆ label    │
# │ ---        ┆ ---        ┆ date       ┆ ---    ┆   ┆ _type     ┆ _disposit ┆ on_risk_s ┆ ---      │
# │ str        ┆ str        ┆ ---        ┆ str    ┆   ┆ ---       ┆ ion       ┆ core      ┆ f64      │
# │            ┆            ┆ str        ┆        ┆   ┆ str       ┆ ---       ┆ ---       ┆          │
# │            ┆            ┆            ┆        ┆   ┆           ┆ str       ┆ f64       ┆          │
# ╞════════════╪════════════╪════════════╪════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count      ┆ 8000       ┆ 8000       ┆ 8000   ┆ … ┆ 8000      ┆ 8000      ┆ 8000.0    ┆ 8000.0   │
# │ null_count ┆ 0          ┆ 0          ┆ 0      ┆ … ┆ 0         ┆ 0         ┆ 0.0       ┆ 0.0      │
# │ mean       ┆ null       ┆ null       ┆ null   ┆ … ┆ null      ┆ null      ┆ 0.7769375 ┆ 0.772875 │
# │ std        ┆ null       ┆ null       ┆ null   ┆ … ┆ null      ┆ null      ┆ 0.219885  ┆ 0.419    │
# │ min        ┆ P00001     ┆ 2021-01-01 ┆ Fall   ┆ … ┆ Medicaid  ┆ Home      ┆ 0.07      ┆ 0.0      │
# │ 25%        ┆ null       ┆ null       ┆ null   ┆ … ┆ null      ┆ null      ┆ 0.63      ┆ 1.0      │
# │ 50%        ┆ null       ┆ null       ┆ null   ┆ … ┆ null      ┆ null      ┆ 0.86      ┆ 1.0      │
# │ 75%        ┆ null       ┆ null       ┆ null   ┆ … ┆ null      ┆ null      ┆ 0.97      ┆ 1.0      │
# │ max        ┆ P08000     ┆ 2023-12-31 ┆ Winter ┆ … ┆ Uninsured ┆ Skilled   ┆ 0.97      ┆ 1.0      │
# │            ┆            ┆            ┆        ┆   ┆           ┆ Nursing   ┆           ┆          │
# └────────────┴────────────┴────────────┴────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
X = df.drop(['label'])
y = df['label']

# Define column groups
numerical_cols = [
    'age', 'comorbidities_count', 'length_of_stay',
    'medications_count', 'followup_visits_last_year',
    'prev_readmissions', 'readmission_risk_score'
]
categorical_cols = [
    'season', 'gender', 'region', 'primary_diagnosis',
    'treatment_type', 'insurance_type', 'discharge_disposition'
]

# %%
# Split Test and Training data
# Convert polars DataFrame and Series to pandas DataFrame and Series
X_train, X_test, y_train, y_test = train_test_split(X.to_pandas(),
                                                    y.to_pandas(),
                                                    test_size=0.2,
                                                    random_state=42,
                                                    stratify=y)

# %%
pl.DataFrame(X_train).describe()
# Out:
# shape: (9, 17)
# ┌────────────┬────────────┬───────────┬────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ statistic  ┆ patient_id ┆ admission ┆ season ┆ … ┆ prev_read ┆ insurance ┆ discharge ┆ readmissi │
# │ ---        ┆ ---        ┆ _date     ┆ ---    ┆   ┆ missions  ┆ _type     ┆ _disposit ┆ on_risk_s │
# │ str        ┆ str        ┆ ---       ┆ str    ┆   ┆ ---       ┆ ---       ┆ ion       ┆ core      │
# │            ┆            ┆ str       ┆        ┆   ┆ f64       ┆ str       ┆ ---       ┆ ---       │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆ str       ┆ f64       │
# ╞════════════╪════════════╪═══════════╪════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ count      ┆ 6400       ┆ 6400      ┆ 6400   ┆ … ┆ 6400.0    ┆ 6400      ┆ 6400      ┆ 6400.0    │
# │ null_count ┆ 0          ┆ 0         ┆ 0      ┆ … ┆ 0.0       ┆ 0         ┆ 0         ┆ 0.0       │
# │ mean       ┆ null       ┆ null      ┆ null   ┆ … ┆ 1.57375   ┆ null      ┆ null      ┆ 0.776792  │
# │ std        ┆ null       ┆ null      ┆ null   ┆ … ┆ 0.899479  ┆ null      ┆ null      ┆ 0.220791  │
# │ min        ┆ P00001     ┆ 2021-01-0 ┆ Fall   ┆ … ┆ 0.0       ┆ Medicaid  ┆ Home      ┆ 0.07      │
# │            ┆            ┆ 1         ┆        ┆   ┆           ┆           ┆           ┆           │
# │ 25%        ┆ null       ┆ null      ┆ null   ┆ … ┆ 1.0       ┆ null      ┆ null      ┆ 0.63      │
# │ 50%        ┆ null       ┆ null      ┆ null   ┆ … ┆ 1.0       ┆ null      ┆ null      ┆ 0.86      │
# │ 75%        ┆ null       ┆ null      ┆ null   ┆ … ┆ 2.0       ┆ null      ┆ null      ┆ 0.97      │
# │ max        ┆ P08000     ┆ 2023-12-3 ┆ Winter ┆ … ┆ 5.0       ┆ Uninsured ┆ Skilled   ┆ 0.97      │
# │            ┆            ┆ 1         ┆        ┆   ┆           ┆           ┆ Nursing   ┆           │
# └────────────┴────────────┴───────────┴────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
# Build preprocessing pipeline
preprocessor = ColumnTransformer(transformers=[
    ('num', RobustScaler(), numerical_cols),
    ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)
])

# Fit on train only, transform both
X_train_scaled = preprocessor.fit_transform(X_train)
X_test_scaled  = preprocessor.transform(X_test)

# %%
feature_names = preprocessor.get_feature_names_out()
print(feature_names)
# Out:
# ['num__age' 'num__comorbidities_count' 'num__length_of_stay'
#  'num__medications_count' 'num__followup_visits_last_year'
#  'num__prev_readmissions' 'num__readmission_risk_score' 'cat__season_Fall'
#  'cat__season_Spring' 'cat__season_Summer' 'cat__season_Winter'
#  'cat__gender_Female' 'cat__gender_Male' 'cat__region_Central'
#  'cat__region_East' 'cat__region_North' 'cat__region_South'
#  'cat__region_West' 'cat__primary_diagnosis_Appendicitis'
#  'cat__primary_diagnosis_COPD' 'cat__primary_diagnosis_Diabetes'
#  'cat__primary_diagnosis_Fracture' 'cat__primary_diagnosis_Heart Failure'
#  'cat__primary_diagnosis_Hypertension' 'cat__primary_diagnosis_Influenza'
#  'cat__primary_diagnosis_Kidney Disease'
#  'cat__primary_diagnosis_Pneumonia' 'cat__primary_diagnosis_Sepsis'
#  'cat__primary_diagnosis_Stroke' 'cat__treatment_type_Conservative'
#  'cat__treatment_type_Interventional' 'cat__treatment_type_Medical'
#  'cat__treatment_type_Surgical' 'cat__insurance_type_Medicaid'
#  'cat__insurance_type_Medicare' 'cat__insurance_type_Private'
#  'cat__insurance_type_Uninsured' 'cat__discharge_disposition_Home'
#  'cat__discharge_disposition_Home Health'
#  'cat__discharge_disposition_Rehab'
#  'cat__discharge_disposition_Skilled Nursing']

# %%
X_train_df = pd.DataFrame(X_train_scaled, columns=feature_names)
X_train_df.describe()
# Out:
#           num__age  num__comorbidities_count  num__length_of_stay  \
# count  6400.000000               6400.000000          6400.000000
# mean      0.020136                  0.161250            -0.066771
# std       0.732484                  0.683461             0.643381
# min      -1.695652                 -1.500000            -1.666667
# 25%      -0.478261                 -0.500000            -0.666667
# 50%       0.000000                  0.000000             0.000000
# 75%       0.521739                  0.500000             0.333333
# max       1.652174                  3.000000             2.333333
#
#        num__medications_count  num__followup_visits_last_year  \
# count             6400.000000                     6400.000000
# mean                -0.172656                       -0.183516
# std                  0.764821                        0.812920
# min                 -2.000000                       -2.000000
# 25%                 -0.666667                       -1.000000
# 50%                  0.000000                        0.000000
# 75%                  0.333333                        0.000000
# max                  3.333333                        3.000000
#
#        num__prev_readmissions  num__readmission_risk_score  cat__season_Fall  \
# count             6400.000000                  6400.000000       6400.000000
# mean                 0.573750                    -0.244729          0.249219
# std                  0.899479                     0.649384          0.432595
# min                 -1.000000                    -2.323529          0.000000
# 25%                  0.000000                    -0.676471          0.000000
# 50%                  0.000000                     0.000000          0.000000
# 75%                  1.000000                     0.323529          0.000000
# max                  4.000000                     0.323529          1.000000
#
#        cat__season_Spring  cat__season_Summer  ...  \
# count         6400.000000         6400.000000  ...
# mean             0.249531            0.247656  ...
# std              0.432776            0.431685  ...
# min              0.000000            0.000000  ...
# 25%              0.000000            0.000000  ...
# 50%              0.000000            0.000000  ...
# 75%              0.000000            0.000000  ...
# max              1.000000            1.000000  ...
#
#        cat__treatment_type_Medical  cat__treatment_type_Surgical  \
# count                  6400.000000                   6400.000000
# mean                      0.449688                      0.245625
# std                       0.497501                      0.430491
# min                       0.000000                      0.000000
# 25%                       0.000000                      0.000000
# 50%                       0.000000                      0.000000
# 75%                       1.000000                      0.000000
# max                       1.000000                      1.000000
#
#        cat__insurance_type_Medicaid  cat__insurance_type_Medicare  \
# count                   6400.000000                   6400.000000
# mean                       0.201250                      0.317969
# std                        0.400966                      0.465724
# min                        0.000000                      0.000000
# 25%                        0.000000                      0.000000
# 50%                        0.000000                      0.000000
# 75%                        0.000000                      1.000000
# max                        1.000000                      1.000000
#
#        cat__insurance_type_Private  cat__insurance_type_Uninsured  \
# count                  6400.000000                    6400.000000
# mean                      0.381406                       0.099375
# std                       0.485770                       0.299188
# min                       0.000000                       0.000000
# 25%                       0.000000                       0.000000
# 50%                       0.000000                       0.000000
# 75%                       1.000000                       0.000000
# max                       1.000000                       1.000000
#
#        cat__discharge_disposition_Home  \
# count                      6400.000000
# mean                          0.040313
# std                           0.196707
# min                           0.000000
# 25%                           0.000000
# 50%                           0.000000
# 75%                           0.000000
# max                           1.000000
#
#        cat__discharge_disposition_Home Health  \
# count                             6400.000000
# mean                                 0.754531
# std                                  0.430398
# min                                  0.000000
# 25%                                  1.000000
# 50%                                  1.000000
# 75%                                  1.000000
# max                                  1.000000
#
#        cat__discharge_disposition_Rehab  \
# count                       6400.000000
# mean                           0.006406
# std                            0.079788
# min                            0.000000
# 25%                            0.000000
# 50%                            0.000000
# 75%                            0.000000
# max                            1.000000
#
#        cat__discharge_disposition_Skilled Nursing
# count                                 6400.000000
# mean                                     0.198750
# std                                      0.399091
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                      1.000000
#
# [8 rows x 41 columns]
